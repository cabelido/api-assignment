# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Import Modules

# %%
#Analysis
# The parabolic nature of the temperature scatter plot shows that there is a tendency for temperature to increase as we approach the equator from north as well as south of the equator.
# The temperature is observed to peak between 20-40 degrees latitude, based on random output.
# Humidity levels tend to be higher in cities located in and within proximity of the equator.
# Wind speeds tend to be lower in cities located in and within proximity of the equator. 
# No observable trend seen for cloudiness.

# %%
# Import Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import requests
import time
import os
import csv
import datetime
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Initialize list for holding latitude, longitude and cities
counter = 0
randlat = []
randlon = []
cities = []

# Create a set of random lat and lng combinations
while len(randlat) < 900:
    lat = np.random.uniform(-90, 90)
    lon = np.random.uniform(-180,180)
    city = citipy.nearest_city(lat, lon).city_name
    if city not in cities:
        randlat.append(lat)
        randlon.append(lon)
        cities.append(city)
        counter += 1

# Create a dataframe to summarize data collected.
locationdf = pd.DataFrame({"City":cities,"Latitude":randlat,"Longitude":randlon,}) 

# Inspect the first 5 rows of the data.
locationdf.head()
# Out:
#             City   Latitude   Longitude
# 0         samusu  -8.356018 -163.397958
# 1  srednekolymsk  66.861635  153.086181
# 2       kalmunai   7.905731   83.851346
# 3         lompoc  26.709507 -125.153750
# 4          bluff -67.651788  161.093059

# %%
#Verify length of cities, as instructed here
len(cities)
# Out:
# 900

# %%
#Check the count for each column of data.
locationdf.count()
# Out:
# City         900
# Latitude     900
# Longitude    900
# dtype: int64

# %%
#Check value counts to ensure no duplications.
locationdf["City"].value_counts()
# Out:
# begles                   1
# kununurra                1
# khasan                   1
# kandava                  1
# bubaque                  1
# arcata                   1
# douentza                 1
# del rio                  1
# erikoussa                1
# chumikan                 1
# gashua                   1
# savannah bight           1
# karaul                   1
# preobrazheniye           1
# belyy yar                1
# monteagudo               1
# loreto                   1
# lagoa                    1
# haibowan                 1
# santana do livramento    1
# kholuy                   1
# yeehaw junction          1
# toora-khem               1
# novyy oskol              1
# san jeronimo             1
# ronde                    1
# mao                      1
# cachoeira do sul         1
# ratnagiri                1
# vila                     1
#                         ..
# senhor do bonfim         1
# oktyabrskiy              1
# itoman                   1
# ossora                   1
# makung                   1
# blonduos                 1
# skerries                 1
# russell                  1
# brigantine               1
# baruun-urt               1
# husavik                  1
# urumqi                   1
# punta arenas             1
# codrington               1
# maniitsoq                1
# vostok                   1
# uni                      1
# manutuke                 1
# porbandar                1
# felidhoo                 1
# pachino                  1
# cockburn town            1
# wanaka                   1
# yoichi                   1
# aykhal                   1
# marzuq                   1
# mogochin                 1
# wah                      1
# nome                     1
# doha                     1
# Name: City, Length: 900, dtype: int64

# %%
# Check data types.
locationdf.dtypes
# Out:
# City          object
# Latitude     float64
# Longitude    float64
# dtype: object

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Initalize lists to be used to collect the data from a series of API Calls.
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []
newcities = []

# Initialize counters to be used.
recordcount = 0
setcount = 0

# %%
# Define url.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# Print below to signal beginning of data retrieval.
print("------------------------")
print("Beginning Data Retrieval")
print("------------------------")

# Run a loop to query weather conditions in each city.
for city in cities:
    query_url = url + "&q=" + city
    
    # Collect weather data and display record count and set count.
    response = requests.get(query_url).json()
    if recordcount < 50:
        recordcount += 1
    else:
        setcount += 1
        recordcount = 0
    # Mark beginning of data retrieval
    print(f"Processing record {recordcount} of set {setcount} | {city}")
         
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        newcities.append(city)
    except:
        print(f"{city} not found!")
        continue
# Mark end of data retrieval        
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | samusu
# samusu not found!
# Processing record 2 of set 0 | srednekolymsk
# Processing record 3 of set 0 | kalmunai
# Processing record 4 of set 0 | lompoc
# Processing record 5 of set 0 | bluff
# Processing record 6 of set 0 | garango
# Processing record 7 of set 0 | chapais
# Processing record 8 of set 0 | pemangkat
# pemangkat not found!
# Processing record 9 of set 0 | qaanaaq
# Processing record 10 of set 0 | poronaysk
# Processing record 11 of set 0 | vaini
# Processing record 12 of set 0 | kruisfontein
# Processing record 13 of set 0 | mount gambier
# Processing record 14 of set 0 | barrow
# Processing record 15 of set 0 | busselton
# Processing record 16 of set 0 | daru
# Processing record 17 of set 0 | hasaki
# Processing record 18 of set 0 | rikitea
# Processing record 19 of set 0 | baglung
# Processing record 20 of set 0 | georgetown
# Processing record 21 of set 0 | port lincoln
# Processing record 22 of set 0 | kapaa
# Processing record 23 of set 0 | yellowknife
# Processing record 24 of set 0 | stokmarknes
# Processing record 25 of set 0 | mys shmidta
# mys shmidta not found!
# Processing record 26 of set 0 | burns lake
# Processing record 27 of set 0 | atuona
# Processing record 28 of set 0 | bredasdorp
# Processing record 29 of set 0 | sitka
# Processing record 30 of set 0 | nanortalik
# Processing record 31 of set 0 | mandalgovi
# Processing record 32 of set 0 | sakakah
# sakakah not found!
# Processing record 33 of set 0 | port elizabeth
# Processing record 34 of set 0 | hilo
# Processing record 35 of set 0 | swellendam
# Processing record 36 of set 0 | saskylakh
# Processing record 37 of set 0 | bilma
# Processing record 38 of set 0 | matara
# Processing record 39 of set 0 | aklavik
# Processing record 40 of set 0 | wah
# wah not found!
# Processing record 41 of set 0 | portland
# Processing record 42 of set 0 | zhigansk
# Processing record 43 of set 0 | mataura
# Processing record 44 of set 0 | victoria
# Processing record 45 of set 0 | mahebourg
# Processing record 46 of set 0 | dianopolis
# dianopolis not found!
# Processing record 47 of set 0 | kodiak
# Processing record 48 of set 0 | cortez
# Processing record 49 of set 0 | souillac
# Processing record 50 of set 0 | high prairie
# Processing record 0 of set 1 | sharan
# Processing record 1 of set 1 | punta arenas
# Processing record 2 of set 1 | vaitupu
# vaitupu not found!
# Processing record 3 of set 1 | attawapiskat
# attawapiskat not found!
# Processing record 4 of set 1 | ribeira grande
# Processing record 5 of set 1 | mezen
# Processing record 6 of set 1 | taolanaro
# taolanaro not found!
# Processing record 7 of set 1 | tumannyy
# tumannyy not found!
# Processing record 8 of set 1 | butaritari
# Processing record 9 of set 1 | ilulissat
# Processing record 10 of set 1 | vestmanna
# Processing record 11 of set 1 | surt
# Processing record 12 of set 1 | mar del plata
# Processing record 13 of set 1 | kuhdasht
# Processing record 14 of set 1 | cayenne
# Processing record 15 of set 1 | chuy
# Processing record 16 of set 1 | khatanga
# Processing record 17 of set 1 | ballangen
# Processing record 18 of set 1 | egvekinot
# Processing record 19 of set 1 | cape town
# Processing record 20 of set 1 | clayton
# Processing record 21 of set 1 | bataipora
# Processing record 22 of set 1 | ushuaia
# Processing record 23 of set 1 | sapa
# Processing record 24 of set 1 | yulara
# Processing record 25 of set 1 | laoag
# Processing record 26 of set 1 | arraial do cabo
# Processing record 27 of set 1 | pokrovsk
# Processing record 28 of set 1 | kabwe
# Processing record 29 of set 1 | ancud
# Processing record 30 of set 1 | cabo san lucas
# Processing record 31 of set 1 | pevek
# Processing record 32 of set 1 | sentyabrskiy
# sentyabrskiy not found!
# Processing record 33 of set 1 | east london
# Processing record 34 of set 1 | sindal
# Processing record 35 of set 1 | xiamen
# Processing record 36 of set 1 | avarua
# Processing record 37 of set 1 | albany
# Processing record 38 of set 1 | nome
# Processing record 39 of set 1 | manokwari
# Processing record 40 of set 1 | gat
# Processing record 41 of set 1 | sarnen
# Processing record 42 of set 1 | sault sainte marie
# Processing record 43 of set 1 | longyearbyen
# Processing record 44 of set 1 | mayumba
# Processing record 45 of set 1 | kyren
# Processing record 46 of set 1 | constitucion
# Processing record 47 of set 1 | hermanus
# Processing record 48 of set 1 | plastun
# Processing record 49 of set 1 | tambun
# Processing record 50 of set 1 | povolzhskiy
# Processing record 0 of set 2 | tubruq
# tubruq not found!
# Processing record 1 of set 2 | saint-pierre
# Processing record 2 of set 2 | tabou
# Processing record 3 of set 2 | coquimbo
# Processing record 4 of set 2 | puerto madryn
# Processing record 5 of set 2 | pimentel
# Processing record 6 of set 2 | saint george
# Processing record 7 of set 2 | tiksi
# Processing record 8 of set 2 | tuktoyaktuk
# Processing record 9 of set 2 | bengkulu
# bengkulu not found!
# Processing record 10 of set 2 | ondorhaan
# ondorhaan not found!
# Processing record 11 of set 2 | belyy yar
# Processing record 12 of set 2 | vao
# Processing record 13 of set 2 | gbadolite
# Processing record 14 of set 2 | torbay
# Processing record 15 of set 2 | geraldton
# Processing record 16 of set 2 | pangnirtung
# Processing record 17 of set 2 | sinnamary
# Processing record 18 of set 2 | carnarvon
# Processing record 19 of set 2 | sao filipe
# Processing record 20 of set 2 | savannah bight
# Processing record 21 of set 2 | bathsheba
# Processing record 22 of set 2 | basco
# Processing record 23 of set 2 | estancia
# Processing record 24 of set 2 | lagoa
# Processing record 25 of set 2 | san vicente
# Processing record 26 of set 2 | belushya guba
# belushya guba not found!
# Processing record 27 of set 2 | talnakh
# Processing record 28 of set 2 | blahodatne
# Processing record 29 of set 2 | katsuura
# Processing record 30 of set 2 | marystown
# Processing record 31 of set 2 | cachoeira do sul
# Processing record 32 of set 2 | turukhansk
# Processing record 33 of set 2 | kerki
# kerki not found!
# Processing record 34 of set 2 | port alfred
# Processing record 35 of set 2 | cherskiy
# Processing record 36 of set 2 | senhor do bonfim
# Processing record 37 of set 2 | bosaso
# Processing record 38 of set 2 | aflu
# aflu not found!
# Processing record 39 of set 2 | isangel
# Processing record 40 of set 2 | madimba
# Processing record 41 of set 2 | tucurui
# Processing record 42 of set 2 | pop
# Processing record 43 of set 2 | amderma
# amderma not found!
# Processing record 44 of set 2 | hobart
# Processing record 45 of set 2 | thompson
# Processing record 46 of set 2 | poum
# Processing record 47 of set 2 | sola
# Processing record 48 of set 2 | jamestown
# Processing record 49 of set 2 | buchanan
# Processing record 50 of set 2 | omsukchan
# Processing record 0 of set 3 | huarmey
# Processing record 1 of set 3 | esmeraldas
# Processing record 2 of set 3 | fairbanks
# Processing record 3 of set 3 | coari
# Processing record 4 of set 3 | dzhusaly
# dzhusaly not found!
# Processing record 5 of set 3 | filadelfia
# Processing record 6 of set 3 | long
# Processing record 7 of set 3 | touros
# Processing record 8 of set 3 | cidreira
# Processing record 9 of set 3 | lata
# Processing record 10 of set 3 | grindavik
# Processing record 11 of set 3 | namatanai
# Processing record 12 of set 3 | maguling
# Processing record 13 of set 3 | ormara
# Processing record 14 of set 3 | san isidro
# Processing record 15 of set 3 | bud
# Processing record 16 of set 3 | hithadhoo
# Processing record 17 of set 3 | sampit
# Processing record 18 of set 3 | shihezi
# Processing record 19 of set 3 | misratah
# Processing record 20 of set 3 | acapulco
# Processing record 21 of set 3 | tasiilaq
# Processing record 22 of set 3 | new norfolk
# Processing record 23 of set 3 | provideniya
# Processing record 24 of set 3 | acarau
# acarau not found!
# Processing record 25 of set 3 | tomatlan
# Processing record 26 of set 3 | sarangani
# Processing record 27 of set 3 | saleaula
# saleaula not found!
# Processing record 28 of set 3 | berlevag
# Processing record 29 of set 3 | san pedro
# Processing record 30 of set 3 | thomasville
# Processing record 31 of set 3 | teguise
# Processing record 32 of set 3 | kahului
# Processing record 33 of set 3 | inhambane
# Processing record 34 of set 3 | puerto ayora
# Processing record 35 of set 3 | kurtamysh
# Processing record 36 of set 3 | manutuke
# Processing record 37 of set 3 | oksfjord
# Processing record 38 of set 3 | ewa beach
# Processing record 39 of set 3 | sorland
# Processing record 40 of set 3 | wahran
# wahran not found!
# Processing record 41 of set 3 | atar
# Processing record 42 of set 3 | russell
# Processing record 43 of set 3 | clyde river
# Processing record 44 of set 3 | bandrele
# Processing record 45 of set 3 | patea
# Processing record 46 of set 3 | nikolskoye
# Processing record 47 of set 3 | quatre cocos
# Processing record 48 of set 3 | sorong
# Processing record 49 of set 3 | santa maria
# Processing record 50 of set 3 | illoqqortoormiut
# illoqqortoormiut not found!
# Processing record 0 of set 4 | vardo
# Processing record 1 of set 4 | pisco
# Processing record 2 of set 4 | grand gaube
# Processing record 3 of set 4 | temaraia
# temaraia not found!
# Processing record 4 of set 4 | bambous virieux
# Processing record 5 of set 4 | eureka
# Processing record 6 of set 4 | baoqing
# Processing record 7 of set 4 | ponta delgada
# Processing record 8 of set 4 | maykain
# maykain not found!
# Processing record 9 of set 4 | norman wells
# Processing record 10 of set 4 | yeppoon
# Processing record 11 of set 4 | khonsa
# Processing record 12 of set 4 | doctor phillips
# Processing record 13 of set 4 | mosquera
# Processing record 14 of set 4 | richards bay
# Processing record 15 of set 4 | san cristobal
# Processing record 16 of set 4 | marsh harbour
# Processing record 17 of set 4 | taburi
# taburi not found!
# Processing record 18 of set 4 | olinda
# Processing record 19 of set 4 | estevan
# Processing record 20 of set 4 | diffa
# Processing record 21 of set 4 | leshukonskoye
# Processing record 22 of set 4 | lima
# Processing record 23 of set 4 | dalvik
# Processing record 24 of set 4 | ponta do sol
# Processing record 25 of set 4 | uni
# Processing record 26 of set 4 | maputo
# Processing record 27 of set 4 | olga
# Processing record 28 of set 4 | iquique
# Processing record 29 of set 4 | roma
# Processing record 30 of set 4 | matadi
# Processing record 31 of set 4 | la asuncion
# Processing record 32 of set 4 | washington
# Processing record 33 of set 4 | tome-acu
# tome-acu not found!
# Processing record 34 of set 4 | saquena
# Processing record 35 of set 4 | castro
# Processing record 36 of set 4 | aykhal
# Processing record 37 of set 4 | dunedin
# Processing record 38 of set 4 | viljandi
# Processing record 39 of set 4 | bandarbeyla
# Processing record 40 of set 4 | neryungri
# Processing record 41 of set 4 | kirakira
# Processing record 42 of set 4 | atbasar
# Processing record 43 of set 4 | vila
# Processing record 44 of set 4 | marzuq
# Processing record 45 of set 4 | nefteyugansk
# Processing record 46 of set 4 | erikoussa
# erikoussa not found!
# Processing record 47 of set 4 | phan thiet
# Processing record 48 of set 4 | payo
# Processing record 49 of set 4 | bolungarvik
# bolungarvik not found!
# Processing record 50 of set 4 | prince albert
# Processing record 0 of set 5 | weiser
# Processing record 1 of set 5 | skerries
# Processing record 2 of set 5 | yangjiang
# Processing record 3 of set 5 | hayden
# Processing record 4 of set 5 | barentsburg
# barentsburg not found!
# Processing record 5 of set 5 | asau
# asau not found!
# Processing record 6 of set 5 | mana
# Processing record 7 of set 5 | pangai
# Processing record 8 of set 5 | camacha
# Processing record 9 of set 5 | council bluffs
# Processing record 10 of set 5 | luanda
# Processing record 11 of set 5 | iqaluit
# Processing record 12 of set 5 | ahuimanu
# Processing record 13 of set 5 | westport
# Processing record 14 of set 5 | codrington
# Processing record 15 of set 5 | vostok
# Processing record 16 of set 5 | kaitangata
# Processing record 17 of set 5 | esperance
# Processing record 18 of set 5 | kholuy
# Processing record 19 of set 5 | girne
# girne not found!
# Processing record 20 of set 5 | macaboboni
# macaboboni not found!
# Processing record 21 of set 5 | igurubi
# Processing record 22 of set 5 | olafsvik
# olafsvik not found!
# Processing record 23 of set 5 | mao
# Processing record 24 of set 5 | novobirilyussy
# Processing record 25 of set 5 | andevoranto
# andevoranto not found!
# Processing record 26 of set 5 | luderitz
# Processing record 27 of set 5 | karkaralinsk
# karkaralinsk not found!
# Processing record 28 of set 5 | fortuna
# Processing record 29 of set 5 | bethel
# Processing record 30 of set 5 | tessalit
# Processing record 31 of set 5 | half moon bay
# Processing record 32 of set 5 | dingle
# Processing record 33 of set 5 | at-bashi
# Processing record 34 of set 5 | brigantine
# Processing record 35 of set 5 | dikson
# Processing record 36 of set 5 | smithers
# Processing record 37 of set 5 | khorramshahr
# Processing record 38 of set 5 | guarapari
# Processing record 39 of set 5 | palmer
# Processing record 40 of set 5 | presidente medici
# Processing record 41 of set 5 | araouane
# Processing record 42 of set 5 | kavaratti
# Processing record 43 of set 5 | villarrobledo
# Processing record 44 of set 5 | kavieng
# Processing record 45 of set 5 | cockburn town
# Processing record 46 of set 5 | saryshagan
# saryshagan not found!
# Processing record 47 of set 5 | parnarama
# Processing record 48 of set 5 | vila franca do campo
# Processing record 49 of set 5 | bozhou
# Processing record 50 of set 5 | ilula
# Processing record 0 of set 6 | nguiu
# nguiu not found!
# Processing record 1 of set 6 | aksarka
# Processing record 2 of set 6 | faanui
# Processing record 3 of set 6 | sur
# Processing record 4 of set 6 | san policarpo
# Processing record 5 of set 6 | iskateley
# Processing record 6 of set 6 | baykalovo
# Processing record 7 of set 6 | tuatapere
# Processing record 8 of set 6 | praia da vitoria
# Processing record 9 of set 6 | reinosa
# Processing record 10 of set 6 | liwale
# Processing record 11 of set 6 | belgaum
# Processing record 12 of set 6 | mecca
# Processing record 13 of set 6 | hamilton
# Processing record 14 of set 6 | chenzhou
# Processing record 15 of set 6 | hovd
# Processing record 16 of set 6 | samarai
# Processing record 17 of set 6 | kargopol
# Processing record 18 of set 6 | meulaboh
# Processing record 19 of set 6 | amberley
# Processing record 20 of set 6 | winneba
# Processing record 21 of set 6 | arvika
# Processing record 22 of set 6 | alyangula
# Processing record 23 of set 6 | kondinskoye
# Processing record 24 of set 6 | ambon
# Processing record 25 of set 6 | carutapera
# Processing record 26 of set 6 | upernavik
# Processing record 27 of set 6 | biltine
# Processing record 28 of set 6 | takoradi
# Processing record 29 of set 6 | yeehaw junction
# yeehaw junction not found!
# Processing record 30 of set 6 | bengkalis
# bengkalis not found!
# Processing record 31 of set 6 | chara
# Processing record 32 of set 6 | barra
# Processing record 33 of set 6 | magistralnyy
# Processing record 34 of set 6 | constantine
# Processing record 35 of set 6 | juneau
# Processing record 36 of set 6 | akureyri
# Processing record 37 of set 6 | guia lopes da laguna
# Processing record 38 of set 6 | auki
# Processing record 39 of set 6 | kamyaran
# Processing record 40 of set 6 | labuhan
# Processing record 41 of set 6 | paciran
# Processing record 42 of set 6 | felidhoo
# felidhoo not found!
# Processing record 43 of set 6 | tornio
# Processing record 44 of set 6 | ambilobe
# Processing record 45 of set 6 | pangody
# Processing record 46 of set 6 | lebu
# Processing record 47 of set 6 | bolshoye sorokino
# bolshoye sorokino not found!
# Processing record 48 of set 6 | kupang
# Processing record 49 of set 6 | saint anthony
# Processing record 50 of set 6 | saint-philippe
# Processing record 0 of set 7 | aguimes
# Processing record 1 of set 7 | yar-sale
# Processing record 2 of set 7 | jiayuguan
# Processing record 3 of set 7 | manaure
# Processing record 4 of set 7 | rocha
# Processing record 5 of set 7 | chumikan
# Processing record 6 of set 7 | miri
# Processing record 7 of set 7 | minab
# Processing record 8 of set 7 | nuevo progreso
# Processing record 9 of set 7 | saint-augustin
# Processing record 10 of set 7 | lashio
# Processing record 11 of set 7 | taoudenni
# Processing record 12 of set 7 | general cepeda
# Processing record 13 of set 7 | la rioja
# Processing record 14 of set 7 | puerto escondido
# Processing record 15 of set 7 | chibombo
# Processing record 16 of set 7 | guerrero negro
# Processing record 17 of set 7 | umm kaddadah
# Processing record 18 of set 7 | nouakchott
# Processing record 19 of set 7 | sambava
# Processing record 20 of set 7 | honningsvag
# Processing record 21 of set 7 | sinop
# Processing record 22 of set 7 | tocopilla
# Processing record 23 of set 7 | baykit
# Processing record 24 of set 7 | kaeo
# Processing record 25 of set 7 | copperas cove
# Processing record 26 of set 7 | fort saint james
# Processing record 27 of set 7 | chisinau
# Processing record 28 of set 7 | khuzdar
# Processing record 29 of set 7 | sevlievo
# Processing record 30 of set 7 | chokurdakh
# Processing record 31 of set 7 | vallenar
# Processing record 32 of set 7 | skibbereen
# Processing record 33 of set 7 | nador
# Processing record 34 of set 7 | galgani
# galgani not found!
# Processing record 35 of set 7 | show low
# Processing record 36 of set 7 | pitimbu
# Processing record 37 of set 7 | veinticinco de mayo
# Processing record 38 of set 7 | meyungs
# meyungs not found!
# Processing record 39 of set 7 | axim
# Processing record 40 of set 7 | port hardy
# Processing record 41 of set 7 | cap malheureux
# Processing record 42 of set 7 | san jeronimo
# Processing record 43 of set 7 | aripuana
# Processing record 44 of set 7 | beeville
# Processing record 45 of set 7 | saint-louis
# Processing record 46 of set 7 | sungaipenuh
# Processing record 47 of set 7 | port macquarie
# Processing record 48 of set 7 | presidencia roque saenz pena
# Processing record 49 of set 7 | kidal
# Processing record 50 of set 7 | sayat
# Processing record 0 of set 8 | andenes
# andenes not found!
# Processing record 1 of set 8 | eyl
# Processing record 2 of set 8 | soyo
# Processing record 3 of set 8 | saldanha
# Processing record 4 of set 8 | charcas
# Processing record 5 of set 8 | urengoy
# Processing record 6 of set 8 | champerico
# Processing record 7 of set 8 | klaksvik
# Processing record 8 of set 8 | riohacha
# Processing record 9 of set 8 | te anau
# Processing record 10 of set 8 | ketchikan
# Processing record 11 of set 8 | ustyuzhna
# Processing record 12 of set 8 | neuquen
# Processing record 13 of set 8 | flinders
# Processing record 14 of set 8 | visnes
# Processing record 15 of set 8 | kununurra
# Processing record 16 of set 8 | ivanteyevka
# Processing record 17 of set 8 | santa cruz del sur
# Processing record 18 of set 8 | ikot ekpene
# Processing record 19 of set 8 | kornwestheim
# Processing record 20 of set 8 | krasnotorka
# Processing record 21 of set 8 | doha
# Processing record 22 of set 8 | chifeng
# Processing record 23 of set 8 | kyshtovka
# Processing record 24 of set 8 | kimbe
# Processing record 25 of set 8 | evensk
# Processing record 26 of set 8 | igarka
# Processing record 27 of set 8 | caranavi
# Processing record 28 of set 8 | gamba
# Processing record 29 of set 8 | avera
# Processing record 30 of set 8 | muros
# Processing record 31 of set 8 | preobrazheniye
# Processing record 32 of set 8 | barra patuca
# Processing record 33 of set 8 | los llanos de aridane
# Processing record 34 of set 8 | dzhebariki-khaya
# Processing record 35 of set 8 | riyadh
# Processing record 36 of set 8 | san quintin
# Processing record 37 of set 8 | altamira
# Processing record 38 of set 8 | aquin
# Processing record 39 of set 8 | vila velha
# Processing record 40 of set 8 | korla
# korla not found!
# Processing record 41 of set 8 | harper
# Processing record 42 of set 8 | okhotsk
# Processing record 43 of set 8 | ferrol
# Processing record 44 of set 8 | rafaela
# Processing record 45 of set 8 | itarema
# Processing record 46 of set 8 | paamiut
# Processing record 47 of set 8 | sorvag
# sorvag not found!
# Processing record 48 of set 8 | linjiang
# Processing record 49 of set 8 | nenjiang
# Processing record 50 of set 8 | kathmandu
# Processing record 0 of set 9 | beloha
# Processing record 1 of set 9 | galle
# Processing record 2 of set 9 | tala
# Processing record 3 of set 9 | anadyr
# Processing record 4 of set 9 | clyde
# Processing record 5 of set 9 | asfi
# asfi not found!
# Processing record 6 of set 9 | dhidhdhoo
# Processing record 7 of set 9 | havoysund
# Processing record 8 of set 9 | tarudant
# tarudant not found!
# Processing record 9 of set 9 | la ronge
# Processing record 10 of set 9 | ouesso
# Processing record 11 of set 9 | nakatunguru
# Processing record 12 of set 9 | launceston
# Processing record 13 of set 9 | boa vista
# Processing record 14 of set 9 | ronde
# Processing record 15 of set 9 | salalah
# Processing record 16 of set 9 | esik
# Processing record 17 of set 9 | manaus
# Processing record 18 of set 9 | bac lieu
# bac lieu not found!
# Processing record 19 of set 9 | naze
# Processing record 20 of set 9 | laguna
# Processing record 21 of set 9 | orshanka
# Processing record 22 of set 9 | mahon
# Processing record 23 of set 9 | lorengau
# Processing record 24 of set 9 | nago
# Processing record 25 of set 9 | bria
# Processing record 26 of set 9 | denizli
# Processing record 27 of set 9 | bima
# Processing record 28 of set 9 | khalkhal
# Processing record 29 of set 9 | nantucket
# Processing record 30 of set 9 | pokosnoye
# Processing record 31 of set 9 | gravelbourg
# Processing record 32 of set 9 | jasper
# Processing record 33 of set 9 | oranjestad
# Processing record 34 of set 9 | grand-santi
# Processing record 35 of set 9 | diamantino
# Processing record 36 of set 9 | piranshahr
# Processing record 37 of set 9 | cerro punta
# Processing record 38 of set 9 | abu dhabi
# Processing record 39 of set 9 | talcahuano
# Processing record 40 of set 9 | erdenet
# Processing record 41 of set 9 | honiara
# Processing record 42 of set 9 | xam nua
# Processing record 43 of set 9 | haibowan
# haibowan not found!
# Processing record 44 of set 9 | khonuu
# khonuu not found!
# Processing record 45 of set 9 | okato
# Processing record 46 of set 9 | comodoro rivadavia
# Processing record 47 of set 9 | omboue
# Processing record 48 of set 9 | san joaquin
# Processing record 49 of set 9 | yatou
# Processing record 50 of set 9 | mayo
# Processing record 0 of set 10 | san andres
# Processing record 1 of set 10 | airai
# Processing record 2 of set 10 | port blair
# Processing record 3 of set 10 | bratsk
# Processing record 4 of set 10 | kichera
# Processing record 5 of set 10 | katobu
# Processing record 6 of set 10 | fomboni
# Processing record 7 of set 10 | inuvik
# Processing record 8 of set 10 | komsomolskiy
# Processing record 9 of set 10 | arlit
# Processing record 10 of set 10 | vestmannaeyjar
# Processing record 11 of set 10 | mehamn
# Processing record 12 of set 10 | schwedt
# schwedt not found!
# Processing record 13 of set 10 | adrar
# Processing record 14 of set 10 | nam tha
# nam tha not found!
# Processing record 15 of set 10 | tsihombe
# tsihombe not found!
# Processing record 16 of set 10 | port keats
# Processing record 17 of set 10 | lahat
# Processing record 18 of set 10 | aden
# Processing record 19 of set 10 | vung tau
# Processing record 20 of set 10 | mareeba
# Processing record 21 of set 10 | lavrentiya
# Processing record 22 of set 10 | shitkino
# Processing record 23 of set 10 | rio grande
# Processing record 24 of set 10 | puntarenas
# Processing record 25 of set 10 | muli
# Processing record 26 of set 10 | niono
# Processing record 27 of set 10 | ossora
# Processing record 28 of set 10 | nouadhibou
# Processing record 29 of set 10 | cabinda
# Processing record 30 of set 10 | bath
# Processing record 31 of set 10 | rawson
# Processing record 32 of set 10 | shimoda
# Processing record 33 of set 10 | kroya
# Processing record 34 of set 10 | deputatskiy
# Processing record 35 of set 10 | loreto
# Processing record 36 of set 10 | arcata
# Processing record 37 of set 10 | karpogory
# Processing record 38 of set 10 | sidrolandia
# Processing record 39 of set 10 | scarborough
# Processing record 40 of set 10 | sao mateus
# Processing record 41 of set 10 | namikupa
# Processing record 42 of set 10 | semey
# Processing record 43 of set 10 | srandakan
# Processing record 44 of set 10 | gambela
# Processing record 45 of set 10 | tiznit
# Processing record 46 of set 10 | waipawa
# Processing record 47 of set 10 | tura
# Processing record 48 of set 10 | hastings
# Processing record 49 of set 10 | jardim
# Processing record 50 of set 10 | virden
# Processing record 0 of set 11 | tokur
# Processing record 1 of set 11 | kudahuvadhoo
# Processing record 2 of set 11 | byron bay
# Processing record 3 of set 11 | floro
# Processing record 4 of set 11 | rio cuarto
# Processing record 5 of set 11 | beringovskiy
# Processing record 6 of set 11 | naryan-mar
# Processing record 7 of set 11 | albanel
# Processing record 8 of set 11 | virtsu
# Processing record 9 of set 11 | bam
# Processing record 10 of set 11 | pafos
# pafos not found!
# Processing record 11 of set 11 | shingu
# Processing record 12 of set 11 | ceres
# Processing record 13 of set 11 | liuzhou
# Processing record 14 of set 11 | rungata
# rungata not found!
# Processing record 15 of set 11 | havelock
# Processing record 16 of set 11 | nizhnyaya tavda
# Processing record 17 of set 11 | necochea
# Processing record 18 of set 11 | dakar
# Processing record 19 of set 11 | santana do livramento
# Processing record 20 of set 11 | oktyabrskiy
# Processing record 21 of set 11 | menongue
# Processing record 22 of set 11 | zabaykalsk
# Processing record 23 of set 11 | timra
# Processing record 24 of set 11 | wangqing
# Processing record 25 of set 11 | masalli
# Processing record 26 of set 11 | jingdezhen
# Processing record 27 of set 11 | kagalnitskaya
# Processing record 28 of set 11 | ichalkaranji
# Processing record 29 of set 11 | begles
# Processing record 30 of set 11 | lukuledi
# Processing record 31 of set 11 | george
# Processing record 32 of set 11 | chilca
# Processing record 33 of set 11 | gizo
# Processing record 34 of set 11 | pingzhuang
# pingzhuang not found!
# Processing record 35 of set 11 | laurel
# Processing record 36 of set 11 | darhan
# Processing record 37 of set 11 | havre-saint-pierre
# Processing record 38 of set 11 | joshimath
# Processing record 39 of set 11 | plouzane
# Processing record 40 of set 11 | marang
# marang not found!
# Processing record 41 of set 11 | litoral del san juan
# litoral del san juan not found!
# Processing record 42 of set 11 | tigre
# Processing record 43 of set 11 | chirongui
# Processing record 44 of set 11 | serov
# Processing record 45 of set 11 | karaul
# karaul not found!
# Processing record 46 of set 11 | yangambi
# Processing record 47 of set 11 | baiyin
# Processing record 48 of set 11 | yoichi
# Processing record 49 of set 11 | voineasa
# Processing record 50 of set 11 | mackay
# Processing record 0 of set 12 | lasa
# Processing record 1 of set 12 | malwan
# malwan not found!
# Processing record 2 of set 12 | sucua
# Processing record 3 of set 12 | del rio
# Processing record 4 of set 12 | guaraciaba do norte
# Processing record 5 of set 12 | baruun-urt
# Processing record 6 of set 12 | villa carlos paz
# Processing record 7 of set 12 | buzuluk
# Processing record 8 of set 12 | faya
# Processing record 9 of set 12 | roebourne
# Processing record 10 of set 12 | chiang klang
# Processing record 11 of set 12 | zhetybay
# zhetybay not found!
# Processing record 12 of set 12 | gashua
# Processing record 13 of set 12 | grand centre
# grand centre not found!
# Processing record 14 of set 12 | kibre mengist
# Processing record 15 of set 12 | key largo
# Processing record 16 of set 12 | paragominas
# Processing record 17 of set 12 | channel-port aux basques
# Processing record 18 of set 12 | lancaster
# Processing record 19 of set 12 | mount isa
# Processing record 20 of set 12 | koutiala
# Processing record 21 of set 12 | padang
# Processing record 22 of set 12 | xichang
# Processing record 23 of set 12 | yumen
# Processing record 24 of set 12 | villamontes
# Processing record 25 of set 12 | boljarovo
# boljarovo not found!
# Processing record 26 of set 12 | bilibino
# Processing record 27 of set 12 | agadir
# Processing record 28 of set 12 | san jose
# Processing record 29 of set 12 | brae
# Processing record 30 of set 12 | borogontsy
# Processing record 31 of set 12 | one hundred mile house
# one hundred mile house not found!
# Processing record 32 of set 12 | nabire
# Processing record 33 of set 12 | emerald
# Processing record 34 of set 12 | jamshedpur
# Processing record 35 of set 12 | bubaque
# Processing record 36 of set 12 | solovetskiy
# solovetskiy not found!
# Processing record 37 of set 12 | muhos
# Processing record 38 of set 12 | novyy oskol
# Processing record 39 of set 12 | gumusyaka
# gumusyaka not found!
# Processing record 40 of set 12 | ko samui
# Processing record 41 of set 12 | ventspils
# Processing record 42 of set 12 | bogande
# Processing record 43 of set 12 | maragogi
# Processing record 44 of set 12 | iisalmi
# Processing record 45 of set 12 | wanaka
# Processing record 46 of set 12 | port said
# Processing record 47 of set 12 | ust-nera
# Processing record 48 of set 12 | flin flon
# Processing record 49 of set 12 | ahipara
# Processing record 50 of set 12 | jalu
# Processing record 0 of set 13 | college
# Processing record 1 of set 13 | san carlos de bariloche
# Processing record 2 of set 13 | weligama
# Processing record 3 of set 13 | goundam
# Processing record 4 of set 13 | morganton
# Processing record 5 of set 13 | sao joao da barra
# Processing record 6 of set 13 | biak
# Processing record 7 of set 13 | port moresby
# Processing record 8 of set 13 | kehychivka
# Processing record 9 of set 13 | urumqi
# urumqi not found!
# Processing record 10 of set 13 | alice
# Processing record 11 of set 13 | camocim
# Processing record 12 of set 13 | mahina
# Processing record 13 of set 13 | tommot
# Processing record 14 of set 13 | anuppur
# Processing record 15 of set 13 | maniitsoq
# Processing record 16 of set 13 | firozpur jhirka
# Processing record 17 of set 13 | itoman
# Processing record 18 of set 13 | sao jose da coroa grande
# Processing record 19 of set 13 | jaque
# jaque not found!
# Processing record 20 of set 13 | sredec
# sredec not found!
# Processing record 21 of set 13 | el alto
# Processing record 22 of set 13 | karratha
# Processing record 23 of set 13 | ratnagiri
# Processing record 24 of set 13 | san remo
# Processing record 25 of set 13 | marathon
# Processing record 26 of set 13 | pedernales
# Processing record 27 of set 13 | ban dung
# Processing record 28 of set 13 | boke
# Processing record 29 of set 13 | shumskiy
# Processing record 30 of set 13 | udachnyy
# Processing record 31 of set 13 | nushki
# Processing record 32 of set 13 | porbandar
# Processing record 33 of set 13 | redmond
# Processing record 34 of set 13 | santa fe
# Processing record 35 of set 13 | santarem
# santarem not found!
# Processing record 36 of set 13 | mwense
# Processing record 37 of set 13 | makung
# makung not found!
# Processing record 38 of set 13 | nizhniy chir
# Processing record 39 of set 13 | gushikawa
# Processing record 40 of set 13 | nizhneyansk
# nizhneyansk not found!
# Processing record 41 of set 13 | spearfish
# Processing record 42 of set 13 | bahia blanca
# Processing record 43 of set 13 | beipiao
# Processing record 44 of set 13 | moa
# Processing record 45 of set 13 | santiago del estero
# Processing record 46 of set 13 | salinas
# Processing record 47 of set 13 | eydhafushi
# Processing record 48 of set 13 | ust-kamchatsk
# ust-kamchatsk not found!
# Processing record 49 of set 13 | krynychky
# Processing record 50 of set 13 | road town
# Processing record 0 of set 14 | humberto de campos
# Processing record 1 of set 14 | zimovniki
# Processing record 2 of set 14 | alofi
# Processing record 3 of set 14 | kasungu
# Processing record 4 of set 14 | maine-soroa
# Processing record 5 of set 14 | tautira
# Processing record 6 of set 14 | kandrian
# Processing record 7 of set 14 | abramovka
# Processing record 8 of set 14 | natal
# Processing record 9 of set 14 | cairns
# Processing record 10 of set 14 | vidor
# Processing record 11 of set 14 | norrtalje
# Processing record 12 of set 14 | severo-kurilsk
# Processing record 13 of set 14 | mazagao
# Processing record 14 of set 14 | mahibadhoo
# Processing record 15 of set 14 | trzcianka
# Processing record 16 of set 14 | eirunepe
# Processing record 17 of set 14 | douentza
# Processing record 18 of set 14 | ixtapa
# Processing record 19 of set 14 | hereford
# Processing record 20 of set 14 | blonduos
# blonduos not found!
# Processing record 21 of set 14 | nelson bay
# Processing record 22 of set 14 | fort-shevchenko
# Processing record 23 of set 14 | fevralsk
# fevralsk not found!
# Processing record 24 of set 14 | luganville
# Processing record 25 of set 14 | pachino
# Processing record 26 of set 14 | gelibolu
# Processing record 27 of set 14 | punta de bombon
# Processing record 28 of set 14 | wufeng
# Processing record 29 of set 14 | monteagudo
# Processing record 30 of set 14 | staryy nadym
# Processing record 31 of set 14 | kloulklubed
# Processing record 32 of set 14 | plast
# Processing record 33 of set 14 | gusau
# Processing record 34 of set 14 | kaohsiung
# Processing record 35 of set 14 | bilecik
# Processing record 36 of set 14 | planaltina
# Processing record 37 of set 14 | abonnema
# Processing record 38 of set 14 | antofagasta
# Processing record 39 of set 14 | bereda
# Processing record 40 of set 14 | lodja
# Processing record 41 of set 14 | log
# Processing record 42 of set 14 | tual
# Processing record 43 of set 14 | port hawkesbury
# Processing record 44 of set 14 | neyvo-rudyanka
# Processing record 45 of set 14 | manakara
# Processing record 46 of set 14 | sisimiut
# Processing record 47 of set 14 | marquette
# Processing record 48 of set 14 | masterton
# Processing record 49 of set 14 | tabiauea
# tabiauea not found!
# Processing record 50 of set 14 | lalibela
# Processing record 0 of set 15 | marcona
# marcona not found!
# Processing record 1 of set 15 | muroto
# Processing record 2 of set 15 | sao miguel do araguaia
# Processing record 3 of set 15 | lagos
# Processing record 4 of set 15 | krasnoselkup
# krasnoselkup not found!
# Processing record 5 of set 15 | birin
# Processing record 6 of set 15 | saint paul
# Processing record 7 of set 15 | ruatoria
# ruatoria not found!
# Processing record 8 of set 15 | calvia
# Processing record 9 of set 15 | marsabit
# Processing record 10 of set 15 | quemado de guines
# Processing record 11 of set 15 | vilyuysk
# Processing record 12 of set 15 | sile
# Processing record 13 of set 15 | akropong
# Processing record 14 of set 15 | lincoln
# Processing record 15 of set 15 | concepcion
# Processing record 16 of set 15 | ranong
# Processing record 17 of set 15 | strathmore
# Processing record 18 of set 15 | grand river south east
# grand river south east not found!
# Processing record 19 of set 15 | buariki
# buariki not found!
# Processing record 20 of set 15 | eregli
# Processing record 21 of set 15 | martinsburg
# Processing record 22 of set 15 | mbanza-ngungu
# Processing record 23 of set 15 | illapel
# Processing record 24 of set 15 | tadine
# Processing record 25 of set 15 | caluquembe
# Processing record 26 of set 15 | sayyan
# Processing record 27 of set 15 | batagay
# Processing record 28 of set 15 | brainerd
# Processing record 29 of set 15 | phrai bung
# phrai bung not found!
# Processing record 30 of set 15 | trincomalee
# Processing record 31 of set 15 | brokopondo
# Processing record 32 of set 15 | kachikau
# kachikau not found!
# Processing record 33 of set 15 | qui nhon
# qui nhon not found!
# Processing record 34 of set 15 | sangar
# Processing record 35 of set 15 | bushehr
# Processing record 36 of set 15 | marmande
# Processing record 37 of set 15 | gigmoto
# Processing record 38 of set 15 | victor rosales
# victor rosales not found!
# Processing record 39 of set 15 | williams lake
# Processing record 40 of set 15 | victoria point
# Processing record 41 of set 15 | hirara
# Processing record 42 of set 15 | ous
# Processing record 43 of set 15 | bur gabo
# bur gabo not found!
# Processing record 44 of set 15 | samalaeulu
# samalaeulu not found!
# Processing record 45 of set 15 | jinchang
# Processing record 46 of set 15 | makakilo city
# Processing record 47 of set 15 | utiroa
# utiroa not found!
# Processing record 48 of set 15 | kindu
# Processing record 49 of set 15 | high rock
# Processing record 50 of set 15 | khasan
# Processing record 0 of set 16 | verkhnyaya inta
# Processing record 1 of set 16 | north bend
# Processing record 2 of set 16 | jacareacanga
# Processing record 3 of set 16 | vanimo
# Processing record 4 of set 16 | kandava
# Processing record 5 of set 16 | savinka
# Processing record 6 of set 16 | kedrovyy
# Processing record 7 of set 16 | hami
# Processing record 8 of set 16 | severo-yeniseyskiy
# Processing record 9 of set 16 | haines junction
# Processing record 10 of set 16 | port hedland
# Processing record 11 of set 16 | sterlibashevo
# Processing record 12 of set 16 | san pedro de macoris
# Processing record 13 of set 16 | atlantic beach
# Processing record 14 of set 16 | hirschaid
# Processing record 15 of set 16 | alamogordo
# Processing record 16 of set 16 | banjar
# Processing record 17 of set 16 | vaitape
# Processing record 18 of set 16 | henties bay
# Processing record 19 of set 16 | sioux lookout
# Processing record 20 of set 16 | muravlenko
# Processing record 21 of set 16 | plettenberg bay
# Processing record 22 of set 16 | umba
# Processing record 23 of set 16 | holme
# Processing record 24 of set 16 | chama
# Processing record 25 of set 16 | ibra
# Processing record 26 of set 16 | qandahar
# qandahar not found!
# Processing record 27 of set 16 | dali
# Processing record 28 of set 16 | mitu
# Processing record 29 of set 16 | steinbach
# Processing record 30 of set 16 | ongandjera
# Processing record 31 of set 16 | brus
# Processing record 32 of set 16 | craigieburn
# Processing record 33 of set 16 | kuvshinovo
# Processing record 34 of set 16 | noumea
# Processing record 35 of set 16 | cockburn harbour
# cockburn harbour not found!
# Processing record 36 of set 16 | la mira
# Processing record 37 of set 16 | zopilotepe
# Processing record 38 of set 16 | husavik
# Processing record 39 of set 16 | katherine
# Processing record 40 of set 16 | rundu
# Processing record 41 of set 16 | black river
# Processing record 42 of set 16 | narsaq
# Processing record 43 of set 16 | yavaros
# Processing record 44 of set 16 | dzhida
# Processing record 45 of set 16 | escarcega
# Processing record 46 of set 16 | magaria
# Processing record 47 of set 16 | sambhal
# Processing record 48 of set 16 | kalmar
# Processing record 49 of set 16 | sokoto
# Processing record 50 of set 16 | breytovo
# Processing record 0 of set 17 | mogochin
# mogochin not found!
# Processing record 1 of set 17 | severnyy
# severnyy not found!
# Processing record 2 of set 17 | khani
# Processing record 3 of set 17 | alice springs
# Processing record 4 of set 17 | toora-khem
# Processing record 5 of set 17 | spornoye
# Processing record 6 of set 17 | banepa
# Processing record 7 of set 17 | buenaventura
# Processing record 8 of set 17 | alotau
# alotau not found!
# Processing record 9 of set 17 | hofn
# Processing record 10 of set 17 | bagdarin
# Processing record 11 of set 17 | northam
# Processing record 12 of set 17 | sultanpur
# Processing record 13 of set 17 | san patricio
# Processing record 14 of set 17 | nichinan
# Processing record 15 of set 17 | cibitoke
# Processing record 16 of set 17 | ugoofaaru
# Processing record 17 of set 17 | kysyl-syr
# Processing record 18 of set 17 | jumla
# Processing record 19 of set 17 | kilindoni
# Processing record 20 of set 17 | kainantu
# Processing record 21 of set 17 | matay
# Processing record 22 of set 17 | nicolas ruiz
# Processing record 23 of set 17 | harnosand
# Processing record 24 of set 17 | palabuhanratu
# palabuhanratu not found!
# Processing record 25 of set 17 | enshi
# Processing record 26 of set 17 | libreville
# Processing record 27 of set 17 | vanino
# Processing record 28 of set 17 | toliary
# toliary not found!
# Processing record 29 of set 17 | burnie
# Processing record 30 of set 17 | murdochville
# Processing record 31 of set 17 | tromso
# Processing record 32 of set 17 | turkistan
# turkistan not found!
# Processing record 33 of set 17 | turayf
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe with all data gathered from the series of API calls.
cityweatherdf = pd.DataFrame({"City" : newcities,
                              "Cloudiness (%)" : cloudiness,
                              "Country" : country,
                              "Date" : date,
                              "Humidity (%)" : humidity,
                              "Latitude" : lat,
                              "Longitude" : lng,
                              "Max Temp (F)" : temp,
                              "Wind Speed (mph)": wind})

# Display first 5 rows of the dataframe
cityweatherdf.head()
# Out:
#             City  Cloudiness (%) Country        Date  Humidity (%)  Latitude  \
# 0  srednekolymsk              93      RU  1562791194            30     67.46
# 1       kalmunai             100      LK  1562791194            81      7.42
# 2         lompoc               1      US  1562791040            68     34.64
# 3          bluff              69      AU  1562791195            84    -23.58
# 4        garango               3      BF  1562791195            54     11.80
#
#    Longitude  Max Temp (F)  Wind Speed (mph)
# 0     153.71         78.10              6.53
# 1      81.82         78.64              1.57
# 2    -120.46         81.00             17.22
# 3     149.07         61.54              1.48
# 4      -0.55         83.67              6.49

# %%
# Display statistical overview
cityweatherdf.describe()
# Out:
#        Cloudiness (%)          Date  Humidity (%)    Latitude  Longitude  \
# count      802.000000  8.020000e+02    802.000000  802.000000  802.00000
# mean        48.844140  1.562791e+09     69.562344   20.505337   16.72081
# std         40.148873  1.280107e+02     21.576545   32.503677   87.06236
# min          0.000000  1.562791e+09      7.000000  -54.810000 -179.17000
# 25%          1.000000  1.562791e+09     55.000000   -5.482500  -60.69250
# 50%         44.500000  1.562791e+09     73.000000   23.025000   19.50500
# 75%         90.000000  1.562791e+09     87.000000   48.605000   90.14750
# max        100.000000  1.562792e+09    100.000000   78.220000  179.32000
#
#        Max Temp (F)  Wind Speed (mph)
# count    802.000000        802.000000
# mean      69.754564          7.212431
# std       14.002082          5.194960
# min       31.470000          0.110000
# 25%       58.515000          3.470000
# 50%       70.540000          5.820000
# 75%       79.900000          9.170000
# max      107.600000         36.910000

# %%
#Perform a count
cityweatherdf.count()
# Out:
# City                802
# Cloudiness (%)      802
# Country             802
# Date                802
# Humidity (%)        802
# Latitude            802
# Longitude           802
# Max Temp (F)        802
# Wind Speed (mph)    802
# dtype: int64

# %%
#Perform value counts.
cityweatherdf["City"].value_counts()
# Out:
# port keats               1
# santana do livramento    1
# douentza                 1
# del rio                  1
# huarmey                  1
# gashua                   1
# savannah bight           1
# nikolskoye               1
# preobrazheniye           1
# monteagudo               1
# baykalovo                1
# lagoa                    1
# nabire                   1
# verkhnyaya inta          1
# novyy oskol              1
# san jeronimo             1
# ronde                    1
# sioux lookout            1
# vestmanna                1
# hovd                     1
# presidente medici        1
# chisinau                 1
# harper                   1
# zopilotepe               1
# arcata                   1
# bubaque                  1
# khasan                   1
# cachoeira do sul         1
# chenzhou                 1
# palmer                   1
#                         ..
# saint-philippe           1
# senhor do bonfim         1
# sharan                   1
# mao                      1
# nelson bay               1
# jasper                   1
# masterton                1
# itoman                   1
# ossora                   1
# ko samui                 1
# skerries                 1
# russell                  1
# brigantine               1
# baruun-urt               1
# husavik                  1
# punta arenas             1
# codrington               1
# maniitsoq                1
# vostok                   1
# uni                      1
# porbandar                1
# pachino                  1
# cockburn town            1
# wanaka                   1
# yoichi                   1
# aykhal                   1
# marzuq                   1
# nome                     1
# manutuke                 1
# doha                     1
# Name: City, Length: 802, dtype: int64

# %%
# Drop null values and duplicates, if any
cleancityweatherdf = cityweatherdf.dropna(how = "any").drop_duplicates(subset=["City", "Wind Speed (mph)"], keep=False)

# Display clean dataframe
cleancityweatherdf
# Out:
#                City  Cloudiness (%) Country        Date  Humidity (%)  \
# 0     srednekolymsk              93      RU  1562791194            30
# 1          kalmunai             100      LK  1562791194            81
# 2            lompoc               1      US  1562791040            68
# 3             bluff              69      AU  1562791195            84
# 4           garango               3      BF  1562791195            54
# 5           chapais              90      CA  1562791196            47
# 6           qaanaaq             100      GL  1562791196            65
# 7         poronaysk             100      RU  1562791196            89
# 8             vaini             100      IN  1562791197            87
# 9      kruisfontein               0      ZA  1562791197            91
# 10    mount gambier              75      AU  1562791197            87
# 11           barrow              83      AR  1562791198            66
# 12        busselton              90      AU  1562791198            74
# 13             daru              62      PG  1562791198            87
# 14           hasaki              75      JP  1562791065            88
# 15          rikitea               5      PF  1562791199            78
# 16          baglung             100      NP  1562791199            92
# 17       georgetown              20      GY  1562791199            78
# 18     port lincoln              75      AU  1562791117            78
# 19            kapaa              75      US  1562791200            79
# 20      yellowknife              75      CA  1562791154            62
# 21      stokmarknes              75      NO  1562791200            87
# 22       burns lake             100      CA  1562791201            83
# 23           atuona               0      PF  1562790955            78
# 24       bredasdorp               0      ZA  1562791201            87
# 25            sitka               7      US  1562791070            61
# 26       nanortalik              79      GL  1562791030            86
# 27       mandalgovi              97      MN  1562791202            40
# 28   port elizabeth              75      US  1562791171            58
# 29             hilo              90      US  1562791203            69
# ..              ...             ...     ...         ...           ...
# 772          sokoto              92      NG  1562791506            43
# 773        breytovo             100      RU  1562791507            92
# 774           khani               0      GE  1562791507            94
# 775   alice springs               0      AU  1562791507            39
# 776      toora-khem              65      RU  1562791508            95
# 777        spornoye              40      RU  1562791508            82
# 778          banepa              75      NP  1562791508           100
# 779    buenaventura              63      CO  1562791508            83
# 780            hofn             100      IS  1562791492            89
# 781        bagdarin              96      RU  1562791511            81
# 782         northam              90      AU  1562791511            87
# 783       sultanpur             100      IN  1562791511            93
# 784    san patricio              98      PY  1562791512            82
# 785        nichinan             100      JP  1562791512           100
# 786        cibitoke              72      BI  1562791512            75
# 787       ugoofaaru             100      MV  1562791512            66
# 788       kysyl-syr              77      RU  1562791513            69
# 789           jumla              92      NP  1562791513            99
# 790       kilindoni               2      TZ  1562791514            78
# 791        kainantu             100      PG  1562791514            97
# 792           matay               0      EG  1562791514            34
# 793    nicolas ruiz              75      MX  1562791515            55
# 794       harnosand              69      SE  1562791515            81
# 795           enshi              92      CN  1562791515            91
# 796      libreville              40      GA  1562791449            94
# 797          vanino              17      RU  1562791516            75
# 798          burnie             100      AU  1562791516            91
# 799    murdochville               0      CA  1562791517            41
# 800          tromso               0      NO  1562791517            76
# 801          turayf               0      SA  1562791517            22
#
#      Latitude  Longitude  Max Temp (F)  Wind Speed (mph)
# 0       67.46     153.71         78.10              6.53
# 1        7.42      81.82         78.64              1.57
# 2       34.64    -120.46         81.00             17.22
# 3      -23.58     149.07         61.54              1.48
# 4       11.80      -0.55         83.67              6.49
# 5       49.78     -74.86         75.20              8.05
# 6       77.48     -69.36         43.54              1.63
# 7       49.22     143.10         49.12              3.18
# 8       15.34      74.49         77.55              7.74
# 9      -34.00      24.73         51.64              4.79
# 10     -37.83     140.78         48.20             21.92
# 11     -38.31     -60.23         52.90              1.88
# 12     -33.64     115.35         48.99              9.91
# 13      -9.07     143.21         71.07              5.68
# 14      35.73     140.83         62.60              6.93
# 15     -23.12    -134.97         73.42             19.04
# 16      28.27      83.59         57.22              1.68
# 17       6.80     -58.16         82.40             11.41
# 18     -34.72     135.86         59.20             30.67
# 19      22.08    -159.32         84.20             11.41
# 20      62.45    -114.38         59.00              9.17
# 21      68.56      14.91         55.40              5.82
# 22      54.23    -125.76         60.27              4.23
# 23      -9.80    -139.03         80.44             18.88
# 24     -34.53      20.04         48.20              4.70
# 25      37.17     -99.65         88.00              4.00
# 26      60.14     -45.24         42.10              5.99
# 27      45.76     106.27         68.74             12.48
# 28      39.31     -74.98         91.99              9.17
# 29      19.71    -155.08         80.60              9.17
# ..        ...        ...           ...               ...
# 772     13.06       5.24         89.07              8.46
# 773     58.30      37.86         49.47              4.54
# 774     41.96      42.96         71.60              2.24
# 775    -23.70     133.88         50.00              8.05
# 776     52.47      96.11         53.25              4.59
# 777     50.84      37.29         57.20              4.47
# 778     27.63      85.52         69.80              6.93
# 779      3.89     -77.07         80.07             11.18
# 780     64.25     -15.21         39.04              1.66
# 781     54.44     113.59         58.30              0.67
# 782    -31.65     116.67         53.60              4.70
# 783     26.26      82.07         78.45              3.98
# 784    -26.98     -56.83         68.20              5.06
# 785     31.65     131.31         79.00              4.00
# 786     -2.89      29.12         62.44              2.53
# 787      5.67      73.00         83.85              4.70
# 788     63.90     122.77         66.04              4.76
# 789     29.28      82.18         56.50              2.21
# 790     -7.91      39.67         79.00             22.01
# 791     -6.29     145.87         55.05              1.88
# 792     28.42      30.79         84.57             16.22
# 793     16.40     -92.53         87.80              4.43
# 794     62.63      17.94         53.60              4.70
# 795     30.29     109.48         62.62              3.51
# 796      0.39       9.45         73.40              9.17
# 797     53.93      40.55         55.99              1.99
# 798    -41.05     145.91         46.99              5.99
# 799     48.96     -65.49         61.72              7.67
# 800     69.65      18.96         57.20              5.82
# 801     31.68      38.65         86.00              6.93
#
# [802 rows x 9 columns]

# %%
# Create a CSV file and save the output of the weather results
outputfile = ("cities.csv")
with open(outputfile, 'w') as datafile:
    cleancityweatherdf.to_csv(outputfile)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Format date to show current date on the plot
date = datetime.datetime.fromtimestamp(int(cityweatherdf["Date"][0])).strftime('%m/%d/%Y')

# %%
# Create and save Latitude vs. Temperature Plot
plt.scatter(x = cleancityweatherdf["Latitude"], y = cleancityweatherdf["Max Temp (F)"], c = "blue", edgecolor = "black")
plt.title("City Latitude Vs Max Temperature ({})".format(date) )
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("Latitude_vs_Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Creat and save Latitude vs. Humidity Plot
plt.scatter(x = cleancityweatherdf["Latitude"], y = cleancityweatherdf["Humidity (%)"], c = "blue", edgecolor = "black")
plt.title("City Latitude vs. Humidity ({})".format(date) )
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("Latitude_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create and save Latitude vs. Cloudiness Plot
plt.scatter(x = cleancityweatherdf["Latitude"], y = cleancityweatherdf["Cloudiness (%)"], c = "blue", edgecolor = "black")
plt.title("City Latitude vs. Cloudiness ({})".format(date) )
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("Latitude_vs_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create and save Latitude vs. Wind Speed Plot
plt.scatter(x = cleancityweatherdf["Latitude"], y = cleancityweatherdf["Wind Speed (mph)"], c = "blue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed ({})".format(date) )
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Latitude_vs_Wind_Speed.png")
